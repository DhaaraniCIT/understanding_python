# %% [markdown]
# <a href="https://colab.research.google.com/github/DhaaraniCIT/understanding_python/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name      : Dhaarani.S
Roll no.  : 1731013
Course    : M.Sc.Software Systems
E-mail    : dhaaranieaswari@gmail.com
Phone no. : 8072178244

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e1f06ff-5e37-42d5-a07e-9b24a201299c" name="files[]" multiple disabled />
#      <output id="result-4e1f06ff-5e37-42d5-a07e-9b24a201299c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import json 

with open('botminds_api.json') as file:
  data = json.load(file)

print(data)
# Out:
# {'Id': '658de64c3036647d5bcf0866cf77dd95', 'FinonId': 'f7da3aa5fe9b438ea1f633090e1617cc', 'SubscriptionId': '8ac75a5af2c644e18ef07af9e32abd3f', 'Version': 0, 'Index': 0, 'DateForOrdering': '0001-01-01T05:30:00+05:30', 'Title': '53155608a8c959dfd9af2337db950133.pdf', 'Url': 'https://portal.botminds.ai/a/webapi/api/browser/getPdfContent?file=f7da3aa5fe9b438ea1f633090e1617cc-a786a3b7ed158a30a9ba8ba129b5bd0d', 'SegmentationLogs': [], 'DocumentUrl': 'https://portal.botminds.ai/a/webapi/api/browser/getResponse/f7da3aa5fe9b438ea1f633090e1617cc-f6854aa031cc8fc5029cca7feef86544_seg', 'SeedPageUrl': 'https://portal.botminds.ai/a/webapi/api/browser/getPdfContent', 'SeedPageKind': 4, 'SeedPageDomain': 'portal.botminds.ai', 'JobId': '94ee941ebbbc45558c12f08d01fff275', 'Summaries': [], 'Annotations': None, 'AnnotationLogs': {'ObjectLabelLogList': {'233840dd5fd84848a7431e8dc387e8dc': {'VoteStatus': 2, 'Index': '1', 'StartXPath': None, 'EndXPath': None, 'PageNumber': '1', 'SegmentType': 'Sub Title',
# ...

# %%
import csv 
for each in data['DocSummary']['LabelSummary']:
  
  if each['LearnerType'] == 0:
    print(each['LabelCount'] )
    with open('Output.csv', mode='w') as output_file:
      output_writer = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
      output_writer.writerow(['LabelName','Keywords'])
      output_writer.writerow([each['LabelCount'],each['LabelCount']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-830fdc8828f5> in <module>()
#       1 import csv
# ----> 2 for each in data['DocSummary']['LabelSummary']:
#       3
#       4   if each['LearnerType'] == 0:
#       5     print(each['LabelCount'] )
#
# NameError: name 'data' is not defined
